# %%
import pickle
import pandas as pd
import numpy as np
df = pickle.load( open( "week1_papers.p", "rb" ) )

# %%
# !pwd

# %%
df['grades'] = 70

# %%
df
# Out:
#    net_ids                                             papers  grades
# 0    cpk48  Calvin Kaler\nSOC1101 \nMemo #1\nA similarity ...      70
# 1    tld68  Trang Le Thu Dau \nSociology 1101 \nProfessor ...      70
# 2    akh89  Anum Hussain\nSOC1101\nWeekly Memo #1: Sociolo...      70
# 3     zkm4  Zach Menchaca \nSOC 1101\n8/30/16\n\nMemo Week...      70
# 4   tmb263  Tabatha Brooks\nMemo 1\nAug. 31, 2016\n\n\tIn ...      70
# 5   jam793  Jacob Markin\nResponse to Getting In\n\tIn Gla...      70
# 6   jcp333  \nThe Gladwell reading discussed the admission...      70
# 7    ec745  Emily Chen (ec745)  Malcolm Gladwell, author o...      70
# 8    sfk49  Sarah Kramer \nSOC 1101 Introduction to Sociol...      70
# 9   jpp235  John Pfingst\nMemo 1\nProfessor Tom Davidson\n...      70
# 10  jcb438  Admissions at colleges and universities have m...      70
# 11   yt396  !"#$%&'()&*''''+,-./'SOC1101 MEMO 1 8/29/1 As ...      70
# ...

# %%
def grader(df):
    grade_list = []
    for row in df.iterrows():
        print row[1]['papers']
        grade = raw_input("Enter a grade for the student [70,80,90]: ")
        grade_list.append(grade)
    return grade_list

# %%
grader(df)
# Out:
# Calvin Kaler
# SOC1101
# Memo #1
# ...
